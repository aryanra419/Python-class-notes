# %%
libraries:-they are collection of modules and functions to perform specific tasks.

pandas:-data manipulation
numpy(numerical python): multi-dimensional arrays and mathematical operations

matplotlib,seaborn,plotly:data visualisation 
statistics:
sklearn(scikit learn):machine learning
keras:deep learning
tensorflow:google
pytorch:facebook

# %%
#pandas is used for data manipulation and we can craete series data and datafarames data using pandas

series:-contains 1d data
dataframe:-contains 2D data
# Out:
#   Cell In[2], line 3
#     series:-contains 1d data
#                      ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
pd.Series([1,3,5,6,7])
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
#3 emp id name email salerty
dict1={"id":[111,112,113],"name":['s','p','k'],"email":['a1@gmail.com','b1@gmail.com','a1@gmail.com'],"salery":['10000','100','4500']}
dict1
# Out:
# {'id': [111, 112, 113],
#  'name': ['s', 'p', 'k'],
#  'email': ['a1@gmail.com', 'b1@gmail.com', 'a1@gmail.com'],
#  'salery': ['10000', '100', '4500']}

# %%
pd.DataFrame(dict1)
# Out:
#     id name         email salery
# 0  111    s  a1@gmail.com  10000
# 1  112    p  b1@gmail.com    100
# 2  113    k  a1@gmail.com   4500

# %%
d1=pd.read_excel("C:\\Users\\ar543\\Downloads\\emp_data.xlsx")
d1
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
d2=pd.read_csv("C:\\Users\\ar543\\Downloads\\studata.txt")
d2
# Out:
#    sid    sname            emialid address  phoneno
# 0    1    priya    priya@gmail.com     dvg     9876
# 1    2  karthik  karthik@gmail.com     blr    12345
# 2    3    karan                NaN     msr    34567

# %%
d3=pd.read_csv("C:\\Users\\ar543\\Downloads\\mtcars.csv")
d3
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
d4=pd.read_table("C:\\Users\\ar543\\Downloads\\chipotle.tsv")
d4
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
d5=pd.read_csv("C:\\Users\\ar543\\Downloads\\chipotle.tsv",sep="\t")
d5
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
d5.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
d5.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
#make data with 500 rows
temp=d5.sample(500,)
temp
# Out:
#       order_id  quantity            item_name  \
# 4330      1728         1                Chips
# 550        230         1  Chips and Guacamole
# 1792       724         1    Canned Soft Drink
# 1165       480         1    Canned Soft Drink
# 1177       484         2        Bottled Water
# ...        ...       ...                  ...
# 4121      1651         1         Chicken Bowl
# 3033      1206         1   Chicken Salad Bowl
# 1728       697         1      Chicken Burrito
# 4228      1688         1           Steak Bowl
# 3500      1405         1        Side of Chips
#
#                                      choice_description item_price
# 4330                                                NaN     $2.15
# 550                                                 NaN     $4.45
# 1792                                             [Coke]     $1.25
# 1165                                        [Diet Coke]     $1.25
# 1177                                                NaN     $2.18
# ...

# %%
d5.shape
# Out:
# (4622, 5)

# %%
#how to extract only rows
d5.shape[1]
# Out:
# 5

# %%
#columns names
d5.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
d5.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
d3.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3=pd.read_csv("C:\\Users\\ar543\\Downloads\\mtcars.csv")

# %%
d3
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
d3.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3['manufacturer']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3[['manufacturer']]
# Out:
#            manufacturer
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 8              Merc 230
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 19       Toyota Corolla
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 30        Maserati Bora
# 31           Volvo 142E

# %%
temp1=d3[['mpg','wt','vs','am']]
temp1
# Out:
#      mpg     wt  vs  am
# 0   21.0  2.620   0   1
# 1   21.0  2.875   0   1
# 2   22.8  2.320   1   1
# 3   21.4  3.215   1   0
# 4   18.7  3.440   0   0
# 5   18.1  3.460   1   0
# 6   14.3  3.570   0   0
# 7   24.4  3.190   1   0
# 8   22.8  3.150   1   0
# 9   19.2  3.440   1   0
# 10  17.8  3.440   1   0
# 11  16.4  4.070   0   0
# 12  17.3  3.730   0   0
# 13  15.2  3.780   0   0
# 14  10.4  5.250   0   0
# 15  10.4  5.424   0   0
# 16  14.7  5.345   0   0
# 17  32.4  2.200   1   1
# 18  30.4  1.615   1   1
# 19  33.9  1.835   1   1
# 20  21.5  2.465   1   0
# 21  15.5  3.520   0   0
# 22  15.2  3.435   0   0
# 23  13.3  3.840   0   0
# 24  19.2  3.845   0   0
# 25  27.3  1.935   1   1
# 26  26.0  2.140   0   1
# 27  30.4  1.513   1   1
# 28  15.8  3.170   0   1
# 29  19.7  2.770   0   1
# 30  15.0  3.570   0   1
# 31  21.4  2.780   1   1

# %%
rename column wt by weight and manufacturer as menu

# %%
d3.rename({"wt":"weight","manufacturer":"manu"},errors="raise",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\702644975.py in ?()
# ----> 1 d3.rename({"wt":"weight","manufacturer":"manu"},errors="raise",axis=1,inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5785         0  1  4
#    5786         2  2  5
#    5787         4  3  6
#    5788         """
# -> 5789         return super()._rename(
#    5790             mapper=mapper,
#    5791             index=index,
#    5792             columns=columns,
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1129                         label
#    1130                         for index, label in enumerate(replacements)
#    1131                         if indexer[index] == -1
# ...

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
#count how many unique values are in cyl column

d3['cyl'].nunique()
# Out:
# 3

# %%
d3['cyl'].unique()
# Out:
# array([6, 4, 8])

# %%
d3.nunique()
# Out:
# manu      32
# mpg       25
# cyl        3
# disp      27
# hp        22
# drat      22
# weight    29
# qsec      30
# vs         2
# am         2
# gear       3
# carb       6
# dtype: int64

# %%
# !git add .

# %%
# !git commit -m "pandas libraries"
# Out:
# [main cc01bad] pandas libraries
#  5 files changed, 4064 insertions(+), 6 deletions(-)
#  create mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/libraries-checkpoint.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 libraries.ipynb

# %%
# !git push
# Out:
# To https://github.com/aryanra419/Python-class-notes
#    4bcdd73..cc01bad  main -> main

# %%
#create half qsec
d3["Half qsec"] = d3["qsec"]/2

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
d3["Car type"] = d3["am"]==1

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...
