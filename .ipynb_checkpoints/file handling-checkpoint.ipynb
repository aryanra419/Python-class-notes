# %%
what is file handling?
it will allow us to crete,read,write,and delete files.
    it is used to store data permanently.

the built function is open() to work with files
common modes:


1) "r" -read
2) "w" -write
3) "a" -append
4) "b" -binary
5) "t" -text
6) "rb" -read binary
7) "wt" -write

File path

relative path: file name
absolute path: directories(complete loc)  + filer name0

# %%
data = open(r"C:\Users\ar543\OneDrive\Desktop\demo.txt","r")

# %%
data.read()
# Out:
# 'hi  good afternoon all'

# %%
data.close()

# %%
data.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.read()
#
# ValueError: I/O operation on closed file.

# %%
d1=open("sample.text")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d1=open("sample.text")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.text'

# %%
a1 = open(r"C:\Users\ar543\OneDrive\Desktop\newdemo.txt","w")
a1.write("Hello")
a1.close()

# %%
a1 = open(r"C:\Users\ar543\OneDrive\Desktop\newdemo.txt","w")
