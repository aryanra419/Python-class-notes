# %%
libraries:-they are collection of modules and functions to perform specific tasks.

pandas:-data manipulation
numpy(numerical python): multi-dimensional arrays and mathematical operations

matplotlib,seaborn,plotly:data visualisation 
statistics:
sklearn(scikit learn):machine learning
keras:deep learning
tensorflow:google
pytorch:facebook

# %%
#pandas is used for data manipulation and we can craete series data and datafarames data using pandas

series:-contains 1d data
dataframe:-contains 2D data
# Out:
#   Cell In[2], line 3
#     series:-contains 1d data
#                      ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
pd.Series([1,3,5,6,7])
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
#3 emp id name email salerty
dict1={"id":[111,112,113],"name":['s','p','k'],"email":['a1@gmail.com','b1@gmail.com','a1@gmail.com'],"salery":['10000','100','4500']}
dict1
# Out:
# {'id': [111, 112, 113],
#  'name': ['s', 'p', 'k'],
#  'email': ['a1@gmail.com', 'b1@gmail.com', 'a1@gmail.com'],
#  'salery': ['10000', '100', '4500']}

# %%
pd.DataFrame(dict1)
# Out:
#     id name         email salery
# 0  111    s  a1@gmail.com  10000
# 1  112    p  b1@gmail.com    100
# 2  113    k  a1@gmail.com   4500

# %%
d1=pd.read_excel("C:\\Users\\ar543\\Downloads\\emp_data.xlsx")
d1
# Out:
#    eid ename   sal  dept
# 0    1    aa  1234    10
# 1    2    bb  2345    20
# 2    3    cc  3214    30
# 3    4    dd  5332    40

# %%
d2=pd.read_csv("C:\\Users\\ar543\\Downloads\\studata.txt")
d2
# Out:
#    sid    sname            emialid address  phoneno
# 0    1    priya    priya@gmail.com     dvg     9876
# 1    2  karthik  karthik@gmail.com     blr    12345
# 2    3    karan                NaN     msr    34567

# %%
d3=pd.read_csv("C:\\Users\\ar543\\Downloads\\mtcars.csv")
d3
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
d4=pd.read_table("C:\\Users\\ar543\\Downloads\\chipotle.tsv")
d4
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
d5=pd.read_csv("C:\\Users\\ar543\\Downloads\\chipotle.tsv",sep="\t")
d5
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
d5.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
d5.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
#make data with 500 rows
temp=d5.sample(500,)
temp
# Out:
#       order_id  quantity            item_name  \
# 204         91         1      Chicken Burrito
# 3670      1469         1        Steak Burrito
# 4596      1826         1  Chips and Guacamole
# 4262      1700         1        Steak Burrito
# 4463      1778         1    Canned Soft Drink
# ...        ...       ...                  ...
# 4506      1792         1         Chicken Bowl
# 3433      1379         1        Steak Burrito
# 3830      1535         1         Chicken Bowl
# 3367      1351         1       Veggie Burrito
# 2974      1182         1           Steak Bowl
#
#                                      choice_description item_price
# 204   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.49
# 3670  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.25
# 4596                                                NaN     $4.45
# 4262  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $11.75
# 4463                                         [Lemonade]     $1.25
# ...

# %%
d5.shape
# Out:
# (4622, 5)

# %%
#how to extract only rows
d5.shape[1]
# Out:
# 5

# %%
#columns names
d5.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
d5.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
d3.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3=pd.read_csv("C:\\Users\\ar543\\Downloads\\mtcars.csv")

# %%
d3
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
d3.manufacturer
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3['manufacturer']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: manufacturer, dtype: object

# %%
d3[['manufacturer']]
# Out:
#            manufacturer
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 8              Merc 230
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 19       Toyota Corolla
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 30        Maserati Bora
# 31           Volvo 142E

# %%
temp1=d3[['mpg','wt','vs','am']]
temp1
# Out:
#      mpg     wt  vs  am
# 0   21.0  2.620   0   1
# 1   21.0  2.875   0   1
# 2   22.8  2.320   1   1
# 3   21.4  3.215   1   0
# 4   18.7  3.440   0   0
# 5   18.1  3.460   1   0
# 6   14.3  3.570   0   0
# 7   24.4  3.190   1   0
# 8   22.8  3.150   1   0
# 9   19.2  3.440   1   0
# 10  17.8  3.440   1   0
# 11  16.4  4.070   0   0
# 12  17.3  3.730   0   0
# 13  15.2  3.780   0   0
# 14  10.4  5.250   0   0
# 15  10.4  5.424   0   0
# 16  14.7  5.345   0   0
# 17  32.4  2.200   1   1
# 18  30.4  1.615   1   1
# 19  33.9  1.835   1   1
# 20  21.5  2.465   1   0
# 21  15.5  3.520   0   0
# 22  15.2  3.435   0   0
# 23  13.3  3.840   0   0
# 24  19.2  3.845   0   0
# 25  27.3  1.935   1   1
# 26  26.0  2.140   0   1
# 27  30.4  1.513   1   1
# 28  15.8  3.170   0   1
# 29  19.7  2.770   0   1
# 30  15.0  3.570   0   1
# 31  21.4  2.780   1   1

# %%
rename column wt by weight and manufacturer as menu
# Out:
#   Cell In[43], line 1
#     rename column wt by weight and manufacturer as menu
#            ^
# SyntaxError: invalid syntax

# %%
d3.rename({"wt":"weight","manufacturer":"manu"},errors="raise",axis=1,inplace=True)

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
#count how many unique values are in cyl column

d3['cyl'].nunique()
# Out:
# 3

# %%
d3['cyl'].unique()
# Out:
# array([6, 4, 8])

# %%
d3.nunique()
# Out:
# manu      32
# mpg       25
# cyl        3
# disp      27
# hp        22
# drat      22
# weight    29
# qsec      30
# vs         2
# am         2
# gear       3
# carb       6
# dtype: int64

# %%
# !git add .

# %%
# !git commit -m "pandas libraries"
# Out:
# [main dfce221] pandas libraries
#  2 files changed, 11612 insertions(+), 460 deletions(-)

# %%
# !git push
# Out:
# To https://github.com/aryanra419/Python-class-notes
#    cc95373..dfce221  main -> main

# %%
#create half qsec
d3["Half qsec"] = d3["qsec"]/2

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
d3["Car type"] = d3["am"].apply(lambda x: "Automatic" if x==1 else "Manual")

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92   3.440  18.90   1   0
# ...

# %%
d3["disp"] = d3["disp"] - 10
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  350.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0
# ...

# %%
del d3["Half qsec"]
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  350.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0
# ...

# %%
d3.drop(columns=["vs","am"])
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  gear  \
# 0             Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46     4
# 1         Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02     4
# 2            Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61     4
# 3        Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44     3
# 4     Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02     3
# 5               Valiant  18.1    6  215.0  105  2.76   3.460  20.22     3
# 6            Duster 360  14.3    8  350.0  245  3.21   3.570  15.84     3
# 7             Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00     4
# 8              Merc 230  22.8    4  130.8   95  3.92   3.150  22.90     4
# 9              Merc 280  19.2    6  157.6  123  3.92   3.440  18.30     4
# 10            Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90     4
# 11           Merc 450SE  16.4    8  265.8  180  3.07   4.070  17.40     3
# ...

# %%
d3
# Out:
#                    manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 5               Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0
# 6            Duster 360  14.3    8  350.0  245  3.21   3.570  15.84   0   0
# 7             Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8              Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 9              Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0
# 10            Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0
# ...

# %%
calculate min,max value of mpg column
# Out:
#   Cell In[60], line 1
#     calculate min,max value of mpg column
#               ^
# SyntaxError: invalid syntax

# %%
d3.mpg.mean()
# Out:
# np.float64(20.090625000000003)

# %%
d3.mpg.median()
# Out:
# 19.2

# %%
d3.mpg.sum()
# Out:
# np.float64(642.9000000000001)

# %%
d3.mpg.max()
# Out:
# 33.9

# %%
d3.mpg.min()
# Out:
# 10.4

# %%
d3.shape
# Out:
# (32, 13)

# %%
d3.head(5)
# Out:
#                 manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0          Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1      Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2         Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 3     Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0
# 4  Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
#
#    gear  carb   Car type
# 0     4     4  Automatic
# 1     4     4  Automatic
# 2     4     1  Automatic
# 3     3     1     Manual
# 4     3     2     Manual

# %%
# 1st five row and column

dataframe slicing:
1) iloc: using index values of rows and column
    var.iloc[rst:rsp:rss,cst:csp:css]

default start value:0
        dtop value: upto end
        step size: 1
# Out:
#   Cell In[68], line 4
#     1) iloc: using index values of rows and column
#      ^
# SyntaxError: unmatched ')'

# %%
d3.iloc[:5,:5]   #slicing
# Out:
#                 manu   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  150.0  110
# 1      Mazda RX4 Wag  21.0    6  150.0  110
# 2         Datsun 710  22.8    4   98.0   93
# 3     Hornet 4 Drive  21.4    6  248.0  110
# 4  Hornet Sportabout  18.7    8  350.0  175

# %%
#exrcat all rows wit last 5 columns

d3.iloc[:,-5:]
# Out:
#     vs  am  gear  carb   Car type
# 0    0   1     4     4  Automatic
# 1    0   1     4     4  Automatic
# 2    1   1     4     1  Automatic
# 3    1   0     3     1     Manual
# 4    0   0     3     2     Manual
# 5    1   0     3     1     Manual
# 6    0   0     3     4     Manual
# 7    1   0     4     2     Manual
# 8    1   0     4     2     Manual
# 9    1   0     4     4     Manual
# 10   1   0     4     4     Manual
# 11   0   0     3     3     Manual
# 12   0   0     3     3     Manual
# 13   0   0     3     3     Manual
# 14   0   0     3     4     Manual
# 15   0   0     3     4     Manual
# 16   0   0     3     4     Manual
# 17   1   1     4     1  Automatic
# 18   1   1     4     2  Automatic
# 19   1   1     4     1  Automatic
# 20   1   0     3     1     Manual
# 21   0   0     3     2     Manual
# 22   0   0     3     2     Manual
# 23   0   0     3     4     Manual
# 24   0   0     3     2     Manual
# 25   1   1     4     1  Automatic
# ...

# %%
d3.iloc[::-1,::-1]
# Out:
#      Car type  carb  gear  am  vs   qsec  weight  drat   hp   disp  cyl   mpg  \
# 31  Automatic     2     4   1   1  18.60   2.780  4.11  109  111.0    4  21.4
# 30  Automatic     8     5   1   0  14.60   3.570  3.54  335  291.0    8  15.0
# 29  Automatic     6     5   1   0  15.50   2.770  3.62  175  135.0    6  19.7
# 28  Automatic     4     5   1   0  14.50   3.170  4.22  264  341.0    8  15.8
# 27  Automatic     2     5   1   1  16.90   1.513  3.77  113   85.1    4  30.4
# 26  Automatic     2     5   1   0  16.70   2.140  4.43   91  110.3    4  26.0
# 25  Automatic     1     4   1   1  18.90   1.935  4.08   66   69.0    4  27.3
# 24     Manual     2     3   0   0  17.05   3.845  3.08  175  390.0    8  19.2
# 23     Manual     4     3   0   0  15.41   3.840  3.73  245  340.0    8  13.3
# 22     Manual     2     3   0   0  17.30   3.435  3.15  150  294.0    8  15.2
# 21     Manual     2     3   0   0  16.87   3.520  2.76  150  308.0    8  15.5
# ...

# %%
# print even indexed rows and odd indexed columns
d3.iloc[0::2,1::2]
# Out:
#      mpg   disp  drat   qsec  am  carb
# 0   21.0  150.0  3.90  16.46   1     4
# 2   22.8   98.0  3.85  18.61   1     1
# 4   18.7  350.0  3.15  17.02   0     2
# 6   14.3  350.0  3.21  15.84   0     4
# 8   22.8  130.8  3.92  22.90   0     2
# 10  17.8  157.6  3.92  18.90   0     4
# 12  17.3  265.8  3.07  17.60   0     3
# 14  10.4  462.0  2.93  17.98   0     4
# 16  14.7  430.0  3.23  17.42   0     4
# 18  30.4   65.7  4.93  18.52   1     2
# 20  21.5  110.1  3.70  20.01   0     1
# 22  15.2  294.0  3.15  17.30   0     2
# 24  19.2  390.0  3.08  17.05   0     2
# 26  26.0  110.3  4.43  16.70   1     2
# 28  15.8  341.0  4.22  14.50   1     4
# 30  15.0  291.0  3.54  14.60   1     8

# %%
#rows = [2,7,11,15,20,23,28]
#columns = [2,6,9,11]

d3.iloc[[2,7,11,15,20,23,28],[2,6,9,11]]
# Out:
#     cyl  weight  am  carb
# 2     4   2.320   1     1
# 7     4   3.190   0     2
# 11    8   4.070   0     3
# 15    8   5.424   0     4
# 20    4   2.465   0     1
# 23    8   3.840   0     4
# 28    8   3.170   1     4

# %% [raw]
# loc: extracting data by location nam
#
# var.loc[strating name:ending name, strating name:ending name]

# %%
#extract 1st 10 rows with 1st 4 columns

d3.loc[0:9,"manu":"disp"]
# Out:
#                 manu   mpg  cyl   disp
# 0          Mazda RX4  21.0    6  150.0
# 1      Mazda RX4 Wag  21.0    6  150.0
# 2         Datsun 710  22.8    4   98.0
# 3     Hornet 4 Drive  21.4    6  248.0
# 4  Hornet Sportabout  18.7    8  350.0
# 5            Valiant  18.1    6  215.0
# 6         Duster 360  14.3    8  350.0
# 7          Merc 240D  24.4    4  136.7
# 8           Merc 230  22.8    4  130.8
# 9           Merc 280  19.2    6  157.6

# %%
d3.loc[31:1,"Car type":"manu"]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d3.loc[30:1,"Car type":"manu"]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d3.loc[::-1 ,"Car type":"manu":-1]
# Out:
#      Car type  carb  gear  am  vs   qsec  weight  drat   hp   disp  cyl   mpg  \
# 31  Automatic     2     4   1   1  18.60   2.780  4.11  109  111.0    4  21.4
# 30  Automatic     8     5   1   0  14.60   3.570  3.54  335  291.0    8  15.0
# 29  Automatic     6     5   1   0  15.50   2.770  3.62  175  135.0    6  19.7
# 28  Automatic     4     5   1   0  14.50   3.170  4.22  264  341.0    8  15.8
# 27  Automatic     2     5   1   1  16.90   1.513  3.77  113   85.1    4  30.4
# 26  Automatic     2     5   1   0  16.70   2.140  4.43   91  110.3    4  26.0
# 25  Automatic     1     4   1   1  18.90   1.935  4.08   66   69.0    4  27.3
# 24     Manual     2     3   0   0  17.05   3.845  3.08  175  390.0    8  19.2
# 23     Manual     4     3   0   0  15.41   3.840  3.73  245  340.0    8  13.3
# 22     Manual     2     3   0   0  17.30   3.435  3.15  150  294.0    8  15.2
# 21     Manual     2     3   0   0  16.87   3.520  2.76  150  308.0    8  15.5
# ...

# %%
d3[d3["gear"]==4]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0     4
# 9         Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
# 17        Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   65.7   52  4.93   1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   61.1   65  4.22   1.835  19.90   1   1     4
# 25       Fiat X1-9  27.3    4   69.0   66  4.08   1.935  18.90   1   1     4
# ...

# %%
# try to extract  4 gear with 6 cyl

d3[(d3["gear"]==4) & (d3["cyl"]==6)]
# Out:
#              manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 9        Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10      Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
#
#     carb   Car type
# 0      4  Automatic
# 1      4  Automatic
# 9      4     Manual
# 10     4     Manual

# %%
# extract data either 2 carb or automatic car details

d3[(d3["carb"]==2) | (d3["Car type"]=="Automatic")]
# Out:
#                  manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0           Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1
# 2          Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1
# 4   Hornet Sportabout  18.7    8  350.0  175  3.15   3.440  17.02   0   0
# 7           Merc 240D  24.4    4  136.7   62  3.69   3.190  20.00   1   0
# 8            Merc 230  22.8    4  130.8   95  3.92   3.150  22.90   1   0
# 17           Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1
# 18        Honda Civic  30.4    4   65.7   52  4.93   1.615  18.52   1   1
# 19     Toyota Corolla  33.9    4   61.1   65  4.22   1.835  19.90   1   1
# 21   Dodge Challenger  15.5    8  308.0  150  2.76   3.520  16.87   0   0
# 22        AMC Javelin  15.2    8  294.0  150  3.15   3.435  17.30   0   0
# 24   Pontiac Firebird  19.2    8  390.0  175  3.08   3.845  17.05   0   0
# ...

# %%
#extract data whose hp between 110 to 120
d3[(d3["hp"]>= 110) & (d3["hp"]<=120)]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0     3
# 27    Lotus Europa  30.4    4   85.1  113  3.77   1.513  16.90   1   1     5
#
#     carb   Car type
# 0      4  Automatic
# 1      4  Automatic
# 3      1     Manual
# 27     2  Automatic

# %%
#extract data weight between 2 to 3 or 6 cyl

d3[(d3["weight"].between(2,3)) | (d3["cyl"]==6)]
# Out:
#               manu   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  150.0  110  3.90   2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  150.0  110  3.90   2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4   98.0   93  3.85   2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  248.0  110  3.08   3.215  19.44   1   0     3
# 5          Valiant  18.1    6  215.0  105  2.76   3.460  20.22   1   0     3
# 9         Merc 280  19.2    6  157.6  123  3.92   3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  157.6  123  3.92   3.440  18.90   1   0     4
# 17        Fiat 128  32.4    4   68.7   66  4.08   2.200  19.47   1   1     4
# 20   Toyota Corona  21.5    4  110.1   97  3.70   2.465  20.01   1   0     3
# 26   Porsche 914-2  26.0    4  110.3   91  4.43   2.140  16.70   0   1     5
# 29    Ferrari Dino  19.7    6  135.0  175  3.62   2.770  15.50   0   1     5
# ...

# %%
d7=pd.read_csv(r"C:\\Users\\ar543\\Downloads\\insurance.csv")

d7
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
d7.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
d7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
d7.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
d7.duplicated().sum()
# Out:
# np.int64(1)

# %%
d7.drop_duplicates(inplace=True)
d7
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1337 rows x 7 columns]

# %%
d7.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
d7.shape
# Out:
# (1337, 7)

# %%
# 1) each region wise total expense

d7.groupby("region")["expenses"].sum().sort_values(ascending=False)
# Out:
# region
# southeast    5363689.80
# northeast    4343668.64
# northwest    4034072.37
# southwest    4012754.82
# Name: expenses, dtype: float64

# %%
d7["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
#gender wise average bmi and expenses

d7.groupby('sex')[['bmi','expenses']].mean().round(2)
# Out:
#           bmi  expenses
# sex
# female  30.38  12569.58
# male    30.95  13975.00

# %%
#each region , each children and smoker class wise total expenses

d7.groupby(['region','children','smoker'])['expenses'].mean()
# Out:
# region     children  smoker
# northeast  0         no         8072.292479
#                      yes       28167.025385
#            1         no         9898.238182
#                      yes       32340.127273
#            2         no        11669.296190
#                      yes       22695.814444
#            3         no         7653.362069
#                      yes       34003.914000
#            4         no        14485.194286
#            5         no         6978.973333
# northwest  0         no         7599.786916
#                      yes       28333.342083
#            1         no         7981.625846
#                      yes       26470.358889
#            2         no         9950.850182
#                      yes       31031.635455
#            3         no        10547.913333
#                      yes       36160.173077
#            4         no         9321.926000
#                      yes       21472.480000
#            5         no         8965.800000
# ...

# %%
pd.pivot_table(data=d7,index=['region'],columns=['smoker','children'],values='expenses',aggfunc='mean')
# Out:
# smoker              no                                                         \
# children             0            1             2             3             4
# region
# northeast  8072.292479  9898.238182  11669.296190   7653.362069  14485.194286
# northwest  7599.786916  7981.625846   9950.850182  10547.913333   9321.926000
# southeast  7060.081624  8016.476164   7519.505833  11986.612083  14451.024000
# southwest  7754.155044  7647.231857   8946.972250   8650.186875   9281.694000
#
# smoker                            yes                              \
# children              5             0             1             2
# region
# northeast   6978.973333  28167.025385  32340.127273  22695.814444
# northwest   8965.800000  28333.342083  26470.358889  31031.635455
# southeast  10115.441667  35515.494500  32503.010455  37619.046667
# southwest   6932.858571  30851.768800  34549.955000  37569.401765
#
# smoker
# children              3         4         5
# region
# ...

# %%
sale1=pd.read_csv(r"C:\\Users\\ar543\\Downloads\\Sales Transactions-2017.csv")
sale2=pd.read_csv(r"C:\Users\ar543\Downloads\Sales Transactions-2018.csv")
sale3=pd.read_csv(r"C:\Users\ar543\Downloads\Sales Transactions-2019.csv")

# %%
sale1
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sale2
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sale3
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
fd = pd.concat([sale1,sale2,sale3],ignore_index=True)
fd
# Out:
#               Date   Voucher               Party            Product  \
# 0         1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1         1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2         1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3         1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4         1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202         NaN       NaN                 NaN                NaN
# 111203         NaN       NaN                 NaN                NaN
# 111204         NaN   Total                   NaN                NaN
# 111205         NaN   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...
