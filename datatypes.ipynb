# %%
'''variable'''
a = 66
A = 12
num = 123
num1 = 456
stu_name = "Aryan"
stu_id = 112
Num11 = 768

# %%
invalid variable
stu num = 98765
1Num = 33
emp@name$ = 'karthik'

# %%
data type
single value data type
int
float
str
complex
bool

# %%
a = 6,3
print(type(a))
# Out:
# <class 'tuple'>

# %%
multivalue data type
list
tuple
set 
dictionary

# %%
a = float(input("Enter a value:"))
print(a)
print(type(a))
b = int(a)
print(b)
print(type(b))
# Out:
# Enter a value: 2.2
# 2.2
# <class 'float'>
# 2
# <class 'int'>

# %% [markdown]
# operator
# arithmetic: + - * / % ** //
# comapasional: == != > < >+ <=
# logical: and or not
# assignment: += -+ *= /= **= //=
# bitwise: &
# memebership: in not in
# identity: is not in

# %%
pgm to read student name, id, email, 3 subject marks out of 100

**************Student Details*********
ID:
NAME:
EMAIL:
SUB1:
SUB2:
SUB3:
TOTAL:
PERCENTAGE:
******all the best********

# %%
a = **************Student Details*********
print(a)
ID = int(input("Enter ID"))

NAME = input("Enter Name"))
EMAIL =  input()
SUB1 = int(input("Enter SUB1:"))
SUB2 = int(input("Enter SUB2:"))
SUB3 = int(input("Enter SUB3:"))
# Out:
#   Cell In[1], line 5
#     NAME = input("Enter Name"))
#                               ^
# SyntaxError: unmatched ')'

# %%
p=int(input("Enter p: "))
t=int(input("Enter t: "))
r=int(input("Enter r: "))

si = (p*t*r)/100
print(si)
# Out:
# Enter p:  12
# Enter t:  12
# Enter r:  32
# 46.08

# %%
units = int(input("enter a value"))
if(units>=0 and units<=100):
    ba = units*0.5
elif(units>100 and units<=200):
    diff_u = units-100
    ba= (100*0.5)+(diff_u*0.75)
elif(units>200):
    diif_u=units-200
    ba=(100*.5)+(100*.75)+(diff_u*1)
else:
    ba=0
    print("invalid input")
print("the total bill amount is:",ba)
# Out:
# enter a value 87
# the total bill amount is: 43.5

# %%
Slicing:
var[start pos:stop pos:inc/dec]
default start pos:0
        stop pos: upto last
        step size: 1

# %%
l1=[23,49,67,10,33,89,75,52,83]

l1[0:4:]
# Out:
# [23, 49, 67, 10]

# %%
l1=[23,49,67,10,33,89,75,52,83]
l1[-4:]
# Out:
# [89, 75, 52, 83]

# %%
#even pos elements
l1[0::2]
# Out:
# [23, 67, 33, 75, 83]

# %%
#0dd pos element
l1=[23,49,67,10,33,89,75,52,83]
l1[1::2]
# Out:
# [49, 10, 89, 52]

# %%
#divisible by 3
l1[3::3]
# Out:
# [10, 75]

# %%
#reverse the list
l1[::-1]
# Out:
# [83, 52, 75, 89, 33, 10, 67, 49, 23]

# %%
#create 3 equal chunks of the list
s=len(l1)//3
s
c1=l1[0:s]
c2=l1[s:(s+s)]
c3=l1[(s+s):]
print(c1,c2,c3)
# Out:
# [23, 49, 67] [10, 33, 89] [75, 52, 83]
