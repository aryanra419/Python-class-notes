# %%
import pandas as pd

# %%
d1= pd.read_csv("C:\\Users\\ar543\\Downloads\\Cars.csv")

# %%
d1
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
d1.shape
# Out:
# (81, 5)

# %%
d1.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
d1.duplicated().sum()
# Out:
# np.int64(0)

# %%
d1.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
# !git add .

# %%
# !git commit -m"data distributio"
# Out:
# [main af1b3c5] data distributio
#  1 file changed, 316 insertions(+), 16 deletions(-)

# %%
# !git push
# Out:
# To https://github.com/aryanra419/Python-class-notes
#    56874c6..af1b3c5  main -> main

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(d1['HP'],d1['MPG'])
plt.xlabel("HP")
plt.ylabel('MPG')
plt.show()

# %%
plt.scatter(d1['VOL'],d1['MPG'])
plt.xlabel("VOL")
plt.ylabel('MPG')
plt.show()

# %%
plt.scatter(d1['SP'],d1['MPG'])
plt.xlabel("SP")
plt.ylabel('MPG')
plt.show()

# %%
plt.scatter(d1['WT'],d1['MPG'])
plt.xlabel("WT")
plt.ylabel('MPG')
plt.show()

# %%
d1.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
Test of /linearity is failed
# Out:
#   Cell In[42], line 1
#     Test of /linearity is failed
#          ^
# SyntaxError: invalid syntax

# %%
no multicolinarity test is also failed

# %%
No auto regression/ autocorrelation test is passed

# %%
x = d1[['HP','VOL','SP','WT']]

# %%
x

# %%
y= d1[['MPG']]
y

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x,y)
y_pred = mlr.predict(x)

# %%
y_pred

# %%
mlr.coef_

# %%
mlr.intercept_

# %%
# !git add .

# %%
# !git commit -m"Data loading"

# %%
# !git push

# %%
((-0.20544372*49)+(-0.33605084*89)+(0.39562692*104.185353)+( 0.40057409*28.762059))+30.67733585215172

# %% [markdown]
# from sklearn.metrics import r2_score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,y_pred)

# %%
error = y-y_pred
error

# %%
plt.scatter(x['HP'],error)
plt.show()

# %%
plt.scatter(x['SP'],error)
plt.show()

# %%
plt.scatter(x['WT'],error)
plt.show()

# %%
# !git add .

# %%
# !git commit -m"graph"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Everything up-to-date

# %%
Homoscadicity test is failed
# Out:
#   Cell In[46], line 1
#     Homoscadicity test is failed
#                   ^
# SyntaxError: invalid syntax

# %%
plt.pdf(error)
plt.show()

# %%
import seaborn as sns

# %%
sns.kdeplot(error)
plt.show()

# %%
train = pd.read_csv("C:\\Users\\ar543\\Downloads\\train.csv")

# %%
train

# %%
train.shape
# Out:
# (699, 2)

# %%
train.isna().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
train.dropna(inplace = True)

# %%
train.isna().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.lmplot(x='x',y='y',data=train)
plt.title('x Vs y')
plt.show()

# %%
sns.distplot(a=error,hist = False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.distplot(a=error,hist = False)
#       2 plt.show()
#
# NameError: name 'error' is not defined

# %%
sns.distplot(a=train['x'],hist = True)
plt.show()
# Out:
# C:\Users\ar543\AppData\Local\Temp\ipykernel_4676\4077700113.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['x'],hist = True)

# %%
from scipy import stats
stats.probplot(x=train['x'],dist='norm',plot=plt)
plt.show()
